# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import ast
import json

# %%
try:
    stopwords.words('english')
except LookupError:
    nltk.download('stopwords')
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')
try:
    nltk.data.find('corpora/wordnet')
except LookupError:
    nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jimmyzhou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv("../data/org-data-unprocessed.csv")

def parse_list_field(x):
    if pd.isna(x):
        return []
    if isinstance(x, list):
        return x
    s = str(x).strip()
    if s == "" or s == "[]":
        return []
    try:
        val = ast.literal_eval(s)
        if isinstance(val, (list, tuple)):
            return list(val)
    except Exception:
        pass
    try:
        val = json.loads(s)
        if isinstance(val, list):
            return val
    except Exception:
        pass
    return [s]

df['Events'] = df['Events'].apply(parse_list_field)
df['News'] = df['News'].apply(parse_list_field)

# %%
def safe_literal_eval(data):
    try:
        if isinstance(data, str) and data.startswith('{'):
            return ast.literal_eval(data)
    except (ValueError, SyntaxError):
        return {}
    return data if isinstance(data, dict) else {}

df['Additional Information'] = df['Additional Information'].apply(safe_literal_eval)

# %%
def clean_data(text):
    if text is None or pd.isna(text):
        return ""
    text = str(text).lower()
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    return " ".join(tokens)

# %%
df['Description'] = df['Description'].apply(clean_data)

# %%
def clean_event_list(event_list):
    if not isinstance(event_list, list):
        return []
    # preserve order while removing duplicates
    seen = set()
    out = []
    for e in event_list:
        if e is None or pd.isna(e):
            continue
        if e not in seen:
            seen.add(e)
            out.append(clean_data(e))
    return out

df['Events'] = df['Events'].apply(clean_event_list)

# %%
df['Document'] = df['Document'].apply(clean_data)

# %%
def clean_news(news):
    if not isinstance(news, list):
        return []
    seen = set()
    unique = []
    for item in news:
        if item is None or pd.isna(item):
            continue
        if item not in seen:
            seen.add(item)
            unique.append(item)
    return [clean_data(article) for article in unique]

df['News'] = df['News'].apply(clean_news)

# %%
df.head()
# Out:
#    Unnamed: 0                      Name  \
# 0           0              100% Triumph
# 1           1              1000 Schools
# 2           2      123 I Like to Ski :)
# 3           3  17 for Peace and Justice
# 4           4                   32 Bars
#
#                                          Description  \
# 0  triumph student organization desires improve s...
# 1  check much fun students helping honduras shh i...
# 2                              join groupme linktree
# 3  organization seek empower students stakeholder...
# 4  bars musical performance troupe dedicated perf...
#
#                               Additional Information  \
# 0  {'mission_statement': 'The purpose of this org...
# 1  {'mission_statement': 'To alleviate extreme po...
# 2  {'mission_statement': 'The purpose of Ski Club...
# 3  {'mission_statement': '17 for Peace and Justic...
# 4  {'mission_statement': 'The mission of 32 Bars ...
#
#                                               Events  \
# 0                                                 []
# 1  [come general body meetings learn whats going ...
# 2  [like ski managing trip mont tremblant go skii...
# 3                                                 []
# 4                                                 []
#
#                                             Document  \
# 0  constitution bylaws triumph last updated artic...
# 1  schools constitution members organization orde...
# 2  like ski ski club constitution article name se...
# 3  preamble members peace justice hereby establis...
# 4  constitution last updates article name section...
#
#                                                 News  \
# 0  [hello hope great week tomorrow triumph hostin...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                  URL
# 0  https://terplink.umd.edu/organization/salvatio...
# 1  https://terplink.umd.edu/organization/1000schools
# 2      https://terplink.umd.edu/organization/skiclub
# 3  https://terplink.umd.edu/organization/17-for-p...
# 4      https://terplink.umd.edu/organization/32-bars

# %%
def clean_additional_info(info: dict):
    info['mission_statement'] = clean_data(info['mission_statement'])
    info['membership_requirements'] = clean_data(info['membership_requirements'])
    info['how_to_get_involved'] = clean_data(info['how_to_get_involved'])
    info['general_meeting_information'] = clean_data(info['general_meeting_information'])
    return info

# %%
df['Additional Information'] = df['Additional Information'].apply(clean_additional_info)

# %%
df.head()
# Out:
#    Unnamed: 0                      Name  \
# 0           0              100% Triumph
# 1           1              1000 Schools
# 2           2      123 I Like to Ski :)
# 3           3  17 for Peace and Justice
# 4           4                   32 Bars
#
#                                          Description  \
# 0  triumph student organization desires improve s...
# 1  check much fun students helping honduras shh i...
# 2                              join groupme linktree
# 3  organization seek empower students stakeholder...
# 4  bars musical performance troupe dedicated perf...
#
#                               Additional Information  \
# 0  {'mission_statement': 'purpose organization sh...
# 1  {'mission_statement': 'alleviate extreme pover...
# 2  {'mission_statement': 'purpose ski club bring ...
# 3  {'mission_statement': 'peace justice exists le...
# 4  {'mission_statement': 'mission bars produce st...
#
#                                               Events  \
# 0                                                 []
# 1  [come general body meetings learn whats going ...
# 2  [like ski managing trip mont tremblant go skii...
# 3                                                 []
# 4                                                 []
#
#                                             Document  \
# 0  constitution bylaws triumph last updated artic...
# 1  schools constitution members organization orde...
# 2  like ski ski club constitution article name se...
# 3  preamble members peace justice hereby establis...
# 4  constitution last updates article name section...
#
#                                                 News  \
# 0  [hello hope great week tomorrow triumph hostin...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                  URL
# 0  https://terplink.umd.edu/organization/salvatio...
# 1  https://terplink.umd.edu/organization/1000schools
# 2      https://terplink.umd.edu/organization/skiclub
# 3  https://terplink.umd.edu/organization/17-for-p...
# 4      https://terplink.umd.edu/organization/32-bars

# %%
cleaned_df = pd.DataFrame(columns=['Name', 'URL', 'Time', 'Information'])
for index, row in df.iterrows():
    org_info = ""
    org_info += str(row['Name']) + ' '
    org_info += str(row['Description']) + ' '
    for event in row['Events']:
        org_info += str(event) + ' '
    org_info += str(row['Document']) + ' '
    for article in row['News']:
        org_info += str(article) + ' '
    add_info = row['Additional Information']
    time = ""
    if isinstance(add_info, dict):
        if add_info.get('meeting_schedule') is not None and add_info.get('expected_time_commitment') is not None:
            time = (add_info.get('meeting_schedule') or "") + (add_info.get('expected_time_commitment') or "") + ' '
        org_info += str(add_info.get('general_meeting_information') or "") + ' '
    cleaned_df.loc[len(cleaned_df)] = [row['Name'], row['URL'], time, org_info]

# %%
cleaned_df
# Out:
#                                                   Name  \
# 0                                         100% Triumph
# 1                                         1000 Schools
# 2                                 123 I Like to Ski :)
# 3                             17 for Peace and Justice
# 4                                              32 Bars
# ..                                                 ...
# 960                             Youth in Public Health
# 961       Zeta Beta Tau - Beta Zeta Epsilon Fraternity
# 962  Zeta Phi Beta Sorority, Incorporated - Eta Eps...
# 963                                Zeta Psi Fraternity
# 964                                     ZETA TAU ALPHA
#
#                                                    URL  \
# 0    https://terplink.umd.edu/organization/salvatio...
# 1    https://terplink.umd.edu/organization/1000schools
# 2        https://terplink.umd.edu/organization/skiclub
# 3    https://terplink.umd.edu/organization/17-for-p...
# 4        https://terplink.umd.edu/organization/32-bars
# ..                                                 ...
# 960  https://terplink.umd.edu/organization/youthinp...
# 961  https://terplink.umd.edu/organization/zeta-bet...
# 962           https://terplink.umd.edu/organization/na
# 963  https://terplink.umd.edu/organization/zeta-psi...
# 964  https://terplink.umd.edu/organization/zeta-tau...
#
#                                                   Time  \
# 0    Evening (6pm-9pm)Low time commitment (1-5 hour...
# 1    Morning (9am-12pm)\nEarly Afternoon (12pm-3pm)...
# 2    Weekends (Saturday and Sunday)Low time commitm...
# 3    Evening (6pm-9pm)\nWeekdays (Monday-Friday)\nW...
# 4    Late Afternoon (3pm-6pm)\nEvening (6pm-9pm)\nL...
# ..                                                 ...
# 960  Late Afternoon (3pm-6pm)\nEvening (6pm-9pm)\nW...
# 961  Late Afternoon (3pm-6pm)\nEvening (6pm-9pm)\nW...
# 962  Early Afternoon (12pm-3pm)\nLate Afternoon (3p...
# 963  Evening (6pm-9pm)\nLate Night (After 9pm)\nWee...
# 964  Late Afternoon (3pm-6pm)\nEvening (6pm-9pm)\nW...
#
#                                            Information
# 0    100% Triumph triumph student organization desi...
# 1    1000 Schools check much fun students helping h...
# 2    123 I Like to Ski :) join groupme linktree lik...
# 3    17 for Peace and Justice organization seek emp...
# 4    32 Bars bars musical performance troupe dedica...
# ..                                                 ...
# 960  Youth in Public Health youth public health dyn...
# 961  Zeta Beta Tau - Beta Zeta Epsilon Fraternity f...
# 962  Zeta Phi Beta Sorority, Incorporated - Eta Eps...
# 963  Zeta Psi Fraternity social fraternity working ...
# 964  ZETA TAU ALPHA zeta tau alpha national social ...
#
# [965 rows x 4 columns]

# %%
cleaned_df.to_csv('../data/org-data-cleaned.csv')
